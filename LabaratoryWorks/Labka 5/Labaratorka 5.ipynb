# %%
#Block 1
import datetime
import csv
import os
class User:
    def __init__(self,user_id:int,name:str,email:str):
        self._id=user_id
        self._name=" ".join(name.split().strip()).title()
        if "@" not in email:
            raise ValueError('ValueError')

        self._email=email.lower()
        self.registration_date=datetime.date.today()

    def __str__(self):
        return f"User(id={self._id},name='{self._name}',email='{self._email}')"
    def __del__(self):
        print(f"User {self._id} deleted")
    @classmethod
    def from_string(cls,data:str):
        parts=[part.strip() for part in data.split(';')]
        return cls(int(parts[0]),parts[1],parts[2])
class Product:
    def __init__(self,id:int,name:str,price:float,category:str):
        self._id=product_id
        self._name=name.strip(),title()
        self._price=float(price)
        self._category=category.title()
    def __str__(self):
        return f"Product(id={self.id},name='{self.name}',price={self.price},category={self.category})"
    def __eq__(self,other):
        if not isinstance(other,Product):
            return False
        return self.id==other.id
    def __hash__(self):
        return hash(self.id)
    def to_dict(self):
        return {'id':self.id,'name':self.name,'price':self.price,'category':self.category}
class Inventory:
    def __init__(self):
        self._products={}

    def add_product(self,product:Product):
        self._products[product.id]=product
    def remove_product(self,product_id:int):
        self._products.pop(product_id,None)
    def get_product(self,product_id:int):
        return self._products.get(product_id)
    def get_all_products(self):
        return list(self._products.values())
    def unique_products(self):
        return set(self._products.values())
    def to_dict(self):
        return {'id':self.id}

    def filter_by_price(self,min_price:float):
        return [p for p in self.get_all_products() if (lambda x: x>=min_price)(p.price)]
class Logger:
    @staticmethod
    def log_action(user:User,action:str,product:Product,filename:str):
        timestamp=datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        log_entry=f"{timestamp};{user._id};{action};{product>id}\n"
        with open(filename,'a',encoding='utf-8') as f:
            f.write(log_entry)
class Order:
    def __init__(self,order_id:int,user:User,product:Product):
        self._order_id=id
        self._user=user.title()
        self._product=products if products else []
    def add_product(self,product: Product):
        self._products[product.id]=product
    def remove_product(self,product_id:int):
        self._products.pop(product_id,None)
    def total_price(self):
        return sum(p.price for p in self.products)

    def most_expensive_products(self,n:int):
        return sorted(self.products, key=lambda p: p.price, reverse=True)[:n]
    def __str__(self):
        return f"Order{self.id} for {self.user._name}, Total:{self.total_price()}"

    def price_srteam(products:list[Product]):
        for p in products:
            yield p.price
class OrderIterator:
    def __init__(self,orders:list[Order]):
        self._order=orders
        self._index=0
    def __iter__(self):
        return self
    def __next__(self):
        if self._index<len(self._orders):
            a=self._orders[self._index]
            self._index+=1
            return a
        raise StopItetator

# %%
class User:
    def __init__(self,user_id:int,name:str,email:str):
        self._id=user_id
        self._name=" ".join(name.split().strip()).title()
        if "@" not in email:
            raise ValueError('ValueError')

        self._email=email.lower()
        self.registration_date=datetime.date.today()

    def __str__(self):
        return f"User(id={self._id},name='{self._name}',email='{self._email}')"
    def __del__(self):
        print(f"User {self._id} deleted")
    @classmethod
    def from_string(cls,data:str):
        parts=[part.strip() for part in data.split(';')]
        return cls(int(parts[0]),parts[1],parts[2])

# %%
class Product:
    def __init__(self,id:int,name:str,price:float,category:str):
        self._id=product_id
        self._name=name.strip(),title()
        self._price=float(price)
        self._category=category.title()
    def __str__(self):
        return f"Product(id={self.id},name='{self.name}',price={self.price},category={self.category})"
    def __eq__(self,other):
        if not isinstance(other,Product):
            return False
        return self.id==other.id
    def __hash__(self):
        return hash(self.id)
    def to_dict(self):
        return {'id':self.id,'name':self.name,'price':self.price,'category':self.category}

# %%
class Inventory:
    def __init__(self):
        self._products={}

    def add_product(self,product:Product):
        self._products[product.id]=product
    def remove_product(self,product_id:int):
        self._products.pop(product_id,None)
    def get_product(self,product_id:int):
        return self._products.get(product_id)
    def get_all_products(self):
        return list(self._products.values())
    def unique_products(self):
        return set(self._products.values())
    def to_dict(self):
        return {'id':self.id}

    def filter_by_price(self,min_price:float):
        return [p for p in self.get_all_products() if (lambda x: x>=min_price)(p.price)]

# %%
class Logger:
    @staticmethod
    def log_action(user:User,action:str,product:Product,filename:str):
        timestamp=datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        log_entry=f"{timestamp};{user._id};{action};{product>id}\n"
        with open(filename,'a',encoding='utf-8') as f:
            f.write(log_entry)

# %%
import datetime
import csv
class User:
    def __init__(self,user_id:int,name:str,email:str):
        self._id=user_id
        self._name=name.strip().title()
        if "@" not in email:
            raise ValueError('ValueError')
        self._email=email.lower()
    def __str__(self):
        return f"User(id={self._id},name='{self._name}',email='{self._email}')"
    def __del__(self):
        return f"User {self._name} deleted)"
    @classmethod
    def from_string(cls, data: str):
        parts=[part.strip() for part in data.split(';')]
        return cls(part[0],part[1],part[2])

class Product:
    def __init__(self,id:int, name:str, price:float, category:str):
        self._id=id
        self._name=name.title()
        self._price=float(price)
        self._category=category.title()
    def __str__(self):
        return f"Product(id={self.id},name='{self.name}',price={self.price},category={self.category})"

    def __hash__(self):
        return hash(self.id)

    def __eq__(self,other):
        if not isinstance(other,Product):
            return False
        return self._id==other.id
    def to_dict(self):
        return{'id':self.id,'name':self.name,'price':self.price,'category':self.category}

class Inventory:
    def __init(self):
        self._products={}
    def add_product(self,product:Product):
        self._products[product.id]=product
    def remove_product(self,product_id:Product):
        self._products.pop(product_id,None)
    def get_product(self,product_id:int):
        return self._products.get(product_id)
    def get_all_products(self):
        return list(self._products.values())
    def unique_product(self):
        return set(self._products.values())
    def to_dict(self):
        return {'id':self._id}
    def filter_by_price(min_price: float):
        return [p for p in self.get_all_products() if (lambda x:x>=min_price)(p.price)]
class Order:
    def __init__(self,order_id:int,user:User,product:Product):
        self._order_id=id
        self._user=user.title()
        self._product=products if products else []
    def total_price(self):
        return sum(p.price for p in self.products)
    def most_expensive_products(self,n):
        return sorted(self.products, key=lambda p:p.price,reverse=True)[:n]
    def price_stream(products:list[Product]):
        for p in products:
            yield p.price
class OrderedItetator:
    def __init__(self,orders:list[Order]):
        self._oeder=orders
        self._index=0
    def __iter__(self):
        return self
    def __next__(self):
        if self._index<len(self._orders):
            a=self._orders[self._index]
            self._index+=1
            return a
        raise StopIterator

# %%
class OrderIterator:
    def __init__(self,orders:list[Order]):
        self._order=orders
        self._index=0
    def __iter__(self):
        return self
    def __next__(self):
        if self._index<len(self._orders):
            a=self._orders[self._index]
            self._index+=1
            return a
        raise StopItetator

# %%
class Order:
    def __init__(self,order_id:int,user:User,product:Product):
        self._order_id=id
        self._user=user.title()
        self._product=products if products else []
    def add_product(self,product: Product):
        self._products[product.id]=product
    def remove_product(self,product_id:int):
        self._products.pop(product_id,None)
    def total_price(self):
        return sum(p.price for p in self.products)

    def most_expensive_products(self,n:int):
        return sorted(self.products, key=lambda p: p.price, reverse=True)[:n]
    def __str__(self):
        return f"Order{self.id} for {self.user._name}, Total:{self.total_price()}"

    def price_srteam(products:list[Product]):
        for p in products:
            yield p.price

# %%
#Block 2
import numpy as np
def get_prices_array(products:list[Product]):
    return np.array([p.price for p in products], dtype=float)
def get_stats(prices_np):
    return (np.mean(prices_np),np.median(prices_np))
def normalize_prices(prices_np):
    p_min,p_max=prices_np.min(),prices_np.max()
    if p_max==p_min: return np.zeros_like(prices_np)
    return (prices_np -p_min)/(p_max-p_min)

def category_analysis(products:list[Product]):
    categories=np.array([p.category for p in products])
    unique_count=len(np.unique(categories))
    return categories,unique_count
def expensive_than_avg(products:list[Product]):
    prices=np.array([p.price for p in products])
    avg=np.mean(prices)
    return [p for p in products if p.price>avg]
def apply_discount(prices_np,discount=0.1):
    return prices_np*(1-discount)
def orders_to_2d(order_list:list[Order]):
    return np.array([[o.total_price()] for o in order_list])
def analyze_order_sums(sums_np):
    avg_order=np.mean(sums_np)
    indices_above_1000=np.where(sums.np>1000)[0]
    return avg_order,indices_above_1000.total()

# %%
import numpy as np
def get_prices_array(products:list[Product]):
    return np.array([p.price for p in products], dtype=float)
def get_stats(prices_np):
    return (np.mean(prices_np),np.median(prices_np))
def normalize_prices(prices_np):
    p_min,p_max=prices_np.min(),prices_np.max()
    if p_max==p_min: return np.zeros_like(prices_np)
    return (prices_np -p_min)/(p_max-p_min)

# %%
def category_analysis(products:list[Product]):
    categories=np.array([p.category for p in products])
    unique_count=len(np.unique(categories))
    return categories,unique_count
def expensive_than_avg(products:list[Product]):
    prices=np.array([p.price for p in products])
    avg=np.mean(prices)
    return [p for p in products if p.price>avg]
def apply_discount(prices_np,discount=0.1):
    return prices_np*(1-discount)
def orders_to_2d(order_list:list[Order]):
    return np.array([[o.total_price()] for o in order_list])
def analyze_order_sums(sums_np):
    avg_order=np.mean(sums_np)
    indices_above_1000=np.where(sums.np>1000)[0]
    return avg_order,indices_above_1000.total()
